# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

img = Image.open(r"C:\Users\patri\git\DeepLearning\DL-HW1\figures\LMS.png")
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()
# Out:
# c:\Users\patri\anaconda3\envs\fml\Lib\site-packages\PIL\Image.py:3186: DecompressionBombWarning: Image size (106364928 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
